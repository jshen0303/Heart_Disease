# %%
import numpy as np # used to create numpy arrays
import pandas as pd # load to dataframes
import matplotlib.pyplot as plt # create plots
import seaborn as sns # create statistical plots (based on matplotlib)

from sklearn.model_selection import train_test_split # import train test split
from sklearn.linear_model import LogisticRegression # import logistic regression model
from sklearn.metrics import accuracy_score # used to find accuracy of model

# %%
heart_data = pd.read_csv('/Users/stellajia/Desktop/UCSB/DS_Club/Heart_Disease-main/heart.csv')

# %% [markdown]
# ## Jeff's Stuff
# exploring data, applying training and testing sets

# %%
heart_data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
heart_data.shape
# Out:
# (303, 14)

# %%
heart_data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
heart_data["target"].value_counts()
# Out:
# 1    165
# 0    138
# Name: target, dtype: int64

# %%
heart_data.groupby("target").mean()
# Out:
#               age       sex        cp    trestbps        chol       fbs  \
# target
# 0       56.601449  0.826087  0.478261  134.398551  251.086957  0.159420
# 1       52.496970  0.563636  1.375758  129.303030  242.230303  0.139394
#
#          restecg     thalach     exang   oldpeak     slope        ca      thal
# target
# 0       0.449275  139.101449  0.550725  1.585507  1.166667  1.166667  2.543478
# 1       0.593939  158.466667  0.139394  0.583030  1.593939  0.363636  2.121212

# %%
# Separate between the data and the label to use supervised learning

# Drop 60th column from x 
x = heart_data.drop(columns="target", axis=1)
# Store 60th column in y
y = heart_data["target"]

print(x,y)
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal
# 0        0   0     1
# 1        0   0     2
# 2        2   0     2
# ...

# %%
# x_train = training data
# x_test = testing data
# y_train = label of training data
# y_test = label of testing data
# test_size = percentage of data to be set aside for testing data
# stratify = data split based on certain category

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, stratify = y, random_state = 1)

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (303, 13) (242, 13) (61, 13)

# %%
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# /Users/stellajia/opt/miniconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
# accuracy on training data
x_train_prediction = model.predict(x_train)
train_accuracy = accuracy_score(x_train_prediction, y_train)
print("Accuracy score: ", train_accuracy)
# Out:
# Accuracy score:  0.859504132231405

# %%
# accuracy on test data
x_test_prediction = model.predict(x_test)
test_accuracy = accuracy_score(x_test_prediction, y_test)
print("Accuracy score of test data: ", test_accuracy)
# Out:
# Accuracy score of test data:  0.8360655737704918

# %%
# Copied data for a rock
data = (63,1,3,145,233,1,0,150,0,2.3,0,0,1)

# convert input to numpy array
input_array = np.asarray(data)

# reshape numpy array to predict for one instance
input_reshape = input_array.reshape(1,-1)

prediction = model.predict(input_reshape)
if prediction[0]==1:
    print("Heart Disease")
else:
    print("Does Not Have Disease")
# Out:
# Heart Disease
# /Users/stellajia/opt/miniconda3/lib/python3.9/site-packages/sklearn/base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# ## Stella's Stuff

# %%
# find correlation among attributes
plt.figure(figsize=(20,10))
sns.heatmap(heart_data.corr(), annot=True, cmap = "viridis")
# Out:
# <AxesSubplot:>

# %% [markdown]
# - positive correlations w/ target: cp, thalach, slope
# - negative correlations w/ target: sex, exang, ca, thal, oldpeak

# %%
# plots relationship between each variable (not very useful)
sns.pairplot(data = heart_data)

# %%
# shape of our data (available in kaggle)
heart_data.hist(figsize=(12,12), layout=(5,3))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'cp'}>],
#        [<AxesSubplot:title={'center':'trestbps'}>,
#         <AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'fbs'}>],
#        [<AxesSubplot:title={'center':'restecg'}>,
#         <AxesSubplot:title={'center':'thalach'}>,
#         <AxesSubplot:title={'center':'exang'}>],
#        [<AxesSubplot:title={'center':'oldpeak'}>,
#         <AxesSubplot:title={'center':'slope'}>,
#         <AxesSubplot:title={'center':'ca'}>],
#        [<AxesSubplot:title={'center':'thal'}>,
#         <AxesSubplot:title={'center':'target'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
# box and whisker plots
heart_data.plot(kind='box', subplots=True, layout=(5,3), figsize=(12,12))
plt.show()

# %%
# distribution of sex and age on presence of heart disease
sns.catplot(data = heart_data, x='sex', y='age', hue='target', palette='ocean')

# %%
# distribution of sex and cholestrol on presence of heart diseaseb
sns.barplot(data=heart_data, x='sex', y='chol', hue='target', palette='summer')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %% [markdown]
# - based on data above, cholestrol doesn't seem to be a big indicator

# %%
heart_data['sex'].value_counts() # 207 males and 96 females
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %%
# thalach had positive correlation so lets test it
heart_data['thal'].value_counts()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %%
sns.countplot(data=heart_data, x='thal', hue='target', palette='PuBu')
# Out:
# <AxesSubplot:xlabel='thal', ylabel='count'>

# %% [markdown]
# - greater chance of heart disease when thal=2

# %%
sns.countplot(data=heart_data, x='thal', hue='sex', palette='cool')
# Out:
# <AxesSubplot:xlabel='thal', ylabel='count'>

# %% [markdown]
# - notice how in thal=2 the # of females and males who have it are very high -> dangerous

# %%
# count of females and males with heart disease 
sns.countplot(x='sex', data=heart_data, palette='spring', hue='target')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %% [markdown]
# - based on the data above, the proportion of females with heart disease is greater

# %%
# recall, ca has a very negative correlation with target
sns.countplot(data=heart_data, x='ca', hue='target')
# Out:
# <AxesSubplot:xlabel='ca', ylabel='count'>

# %% [markdown]
# ca: number of major vessels (0-3) colored by fluorosopy
# - less vessels has higher probability of heart disease

# %%
# recall, cp has positive correlation with target
sns.countplot(data=heart_data, x='cp', hue='target', palette='winter')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
# cp in relation to sex
sns.countplot(data=heart_data, x='cp', hue='sex', palette='BrBG')
# Out:
# <AxesSubplot:xlabel='cp', ylabel='count'>

# %%
# identify common cholestrol levels for heart disease among sex
sns.boxplot(data=heart_data, x='sex', y='chol', hue='target', palette='seismic')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='chol'>

# %%
sns.barplot(data=heart_data, x='sex', y='cp', hue='target', palette='ocean')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='cp'>

# %%
sns.barplot(x='sex', y='oldpeak', hue='target', palette='rainbow', data=heart_data)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='oldpeak'>

# %% [markdown]
# - if you're not resting well you're prone ot have heart disease

# %% [markdown]
# ### Cross Tables

# %%
gen = pd.crosstab(heart_data['sex'], heart_data['target'])
print(gen)
# Out:
# target    0   1
# sex
# 0        24  72
# 1       114  93

# %%
gen.plot(kind='bar', stacked=True, color=['blue', 'purple'], grid=False)
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
temp = pd.crosstab(heart_data['sex'], columns=[heart_data['thal']], margins=True)
temp
# Out:
# thal  0   1    2    3  All
# sex
# 0     1   1   79   15   96
# 1     1  17   87  102  207
# All   2  18  166  117  303

# %%
temp.plot(kind='bar', stacked=True)
plt.show()

# %%
temp=pd.crosstab(index=heart_data['target'], columns=[heart_data['thal']], margins=True)
temp
# Out:
# thal    0   1    2    3  All
# target
# 0       1  12   36   89  138
# 1       1   6  130   28  165
# All     2  18  166  117  303

# %%
temp.plot(kind='bar', stacked=True)
plt.show()
